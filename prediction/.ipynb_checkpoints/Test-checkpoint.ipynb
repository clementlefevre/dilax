# %%
from model import data_store,db_manager
import pandas as pd
import urllib2
from requests.utils import quote
import json
from collections import namedtuple
import pprint
import difflib
import numpy as np
import datetime
from helper.data_helper import reindex_weather_intraday, match_coordinates

# %%
db_params = {'db_user': 'dwe-closed', 'db_name': 'DWE_CLOSED_2013',
                 'db_port': '5432', 'db_pwd': '6EVAqWxOsX2Ao', 'db_url': 'localhost'}

# db_params = {'db_user': 'dwe-arcadia', 'db_name': 'DWE_ARCADIA_2015',
#                  'db_port': '5432', 'db_pwd': 'VtJ5Cw3PKuOi4i3b',
#                  'db_url': 'localhost'}


db =  db_manager.DB_manager(db_params=db_params)
# Out:
# 2016-11-09 05:47:25,012 [INFO ]  engine createdEngine(postgresql://dwe-closed:***@localhost:5432/DWE_CLOSED_2013)

# %%
db.public_holidays.to_csv('test/data/public_holidays_sample3.csv', sep=";")

# %%
df_weather_hour = db.weather_intraday

df_weather_day = db.weather_day

df_sites = db.sites

df_weather_hour = pd.merge(df_weather_hour,
                               df_weather_day[['id', 'latitude', 'longitude']],
                               left_on='idparent',
                               right_on='id')

df_weather_hour[['timestamp', 'temperature',
                     'cloudamount', 'weathersituation',
                     'latitude', 'longitude']]

df_weather_hour = reindex_weather_intraday(df_weather_hour)
df_weather_hour['hour']= df_weather_hour['timestamp'].dt.hour
df_weather_hour['date_']= df_weather_hour['timestamp'].dt.date
df_weather_hour.head()
# Out:
#             timestamp  id_x  idparent  utctimestamp  temperature  cloudamount  \
# 0 2015-05-08 18:00:00  81.0       1.0  1.431101e+12    21.000000          2.0
# 1 2015-05-08 19:00:00  81.0       1.0  1.431101e+12    21.000000          2.0
# 2 2015-05-08 20:00:00  82.0       1.0  1.431108e+12    19.400000          NaN
# 3 2015-05-08 21:00:00  82.0       1.0  1.431108e+12    19.400000          NaN
# 4 2015-05-08 22:00:00  83.0       1.0  1.431115e+12    17.799999          NaN
#
#    weathersituation  id_y  latitude  longitude          coord  hour  \
# 0               1.0   1.0    48.142     11.576  48.142;11.576    18
# 1               1.0   1.0    48.142     11.576  48.142;11.576    19
# 2               3.0   1.0    48.142     11.576  48.142;11.576    20
# 3               3.0   1.0    48.142     11.576  48.142;11.576    21
# 4               4.0   1.0    48.142     11.576  48.142;11.576    22
#
#         date_
# 0  2015-05-08
# 1  2015-05-08
# 2  2015-05-08
# 3  2015-05-08
# ...

# %%
df_weather_coord = df_weather_hour[['latitude', 'longitude']].drop_duplicates()
df_weather_coord
# Out:
#         latitude  longitude
# 0         48.142     11.576
# 12711        NaN        NaN
# 21273     48.776      9.176
# 28275     49.452     11.074
# 38134     50.081      8.244
# 50845     50.110      8.682
# 63555     51.224      6.774
# 76266     52.276      8.042
# 88978     52.505     13.335
# 101688    53.550      9.995
# 114400    53.654     10.091

# %%
df_weather_coord_matched = match_coordinates(df_weather_coord,df_sites)
# Out:
# 2016-11-09 05:47:35,194 [WARNI]  ("'DataFrame' object has no attribute 'idbldsite'",)

# %%
df_weather_coord_matched_with_sites = pd.merge(df_weather_coord_matched,df_sites, left_on=['latitude_closest','longitude_closest'], right_on=['latitude','longitude'])

# %%
df_weather_coord_matched_with_sites[['idbldsite','latitude_x','longitude_x']]
# Out:
#     idbldsite  latitude_x  longitude_x
# 0           3      48.142       11.576
# 1           4      48.142       11.576
# 2          12         NaN          NaN
# 3          12      48.776        9.176
# 4          10      49.452       11.074
# 5           7      50.081        8.244
# 6          11      50.110        8.682
# 7           5      51.224        6.774
# 8           6      51.224        6.774
# 9           9      52.276        8.042
# 10          8      52.505       13.335
# 11          1      53.550        9.995
# 12          2      53.654       10.091

# %%
training = pd.read_csv('data/test_training_data.csv',parse_dates=['date_time'])
training['hour']= training['date_time'].dt.hour
training['date']= training['date_time'].dt.date

# %%
training.head()

# %%
merged = pd.merge(training,df_weather_hour,left_on=['date_time', 'hour'], right_on=['timestamp','hour'], suffixes=['_sites', '_weather'])
merged
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-a3af6df1f4dc> in <module>()
# ----> 1 merged = pd.merge(training,df_weather_hour,left_on=['date_time', 'hour'], right_on=['timestamp','hour'], suffixes=['_sites', '_weather'])
#       2 merged
#
# NameError: name 'training' is not defined

# %%
test = pd.read_csv('data/test_merge_region_hour.csv')

test[test.idbldsite==12]
# Out:
#       Unnamed: 0  idbldsite  latitude  longitude  compensatedin  \
# 0              0         12  48.77663    9.17633             22
# 1              1         12  48.77663    9.17633              7
# 2              2         12  48.77663    9.17633             21
# 3              3         12  48.77663    9.17633             11
# 4              4         12  48.77663    9.17633             20
# 5              5         12  48.77663    9.17633             15
# 6              6         12  48.77663    9.17633             14
# 7              7         12  48.77663    9.17633             11
# 8              8         12  48.77663    9.17633              0
# 9              9         12  48.77663    9.17633              0
# 10            10         12  48.77663    9.17633              0
# 11            11         12  48.77663    9.17633              0
# 12            12         12  48.77663    9.17633              0
# 13            13         12  48.77663    9.17633              0
# ...
